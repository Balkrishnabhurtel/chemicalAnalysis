# %% [markdown]
# # Correlation of PCFS PH Time Series

# %%
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
from statsmodels.multivariate.manova import MANOVA
import statsmodels  as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
from typing import Literal
from statsmodels.graphics.factorplots import interaction_plot
import statsmodels.stats.multicomp as multi
import seaborn as sns
import statsmodels as sm
from statsmodels.stats.anova import anova_lm

# %%
df=pd.read_excel('Time Series.xlsx','2019 PCFS Time Series')

# %%
df.head(108)
# Out:
#      Rep  Trt Depth  WW19  SW19  WW20  SW20
# 0      1    1   0-3  4.15  4.65  4.76   NaN
# 1      1    2   0-3  5.06  5.40  5.38  5.39
# 2      1    3   0-3  5.45  6.04  6.10  6.26
# 3      1    4   0-3  4.45  4.52  4.58  4.62
# 4      1    5   0-3  4.98  5.65  5.75  5.88
# ..   ...  ...   ...   ...   ...   ...   ...
# 103    4    5  6-12  5.11  5.08  4.53  4.74
# 104    4    6  6-12  4.74  5.34  4.97  4.93
# 105    4    7  6-12  4.71  5.16  4.82  4.75
# 106    4    8  6-12  4.76  5.18  4.82  5.09
# 107    4    9  6-12  4.89  5.06  4.75  4.95
#
# [108 rows x 7 columns]

# %% [markdown]
# # Data Visualization

# %% [markdown]
# **CORELATION**

# %%
sns.pairplot(df,vars=['WW19','SW19','WW20','SW20'],kind='reg',size=1.5);
# Out:
# C:\Users\19292\AppData\Local\Programs\Common\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(df,hue='Depth',vars=['WW19','SW19','WW20','SW20'],size=1.5);
# Out:
# C:\Users\19292\AppData\Local\Programs\Common\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(df, kind='reg',hue='Depth',vars=['WW19','SW19','WW20','SW20'],size=1.5);
# Out:
# C:\Users\19292\AppData\Local\Programs\Common\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_83c28_row0_col0, #T_83c28_row1_col1, #T_83c28_row2_col2, #T_83c28_row3_col3, #T_83c28_row4_col4, #T_83c28_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_83c28_row0_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_83c28_row0_col2, #T_83c28_row0_col3, #T_83c28_row0_col4, #T_83c28_row0_col5, #T_83c28_row5_col0, #T_83c28_row5_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_83c28_row1_col0 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_83c28_row1_col2 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_83c28_row1_col3 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_83c28_row1_col4 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_83c28_row1_col5 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_83c28_row2_col0 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_83c28_row2_col1 {
#   background-color: #536edd;
# ...

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
# Out:
# <AxesSubplot:>
