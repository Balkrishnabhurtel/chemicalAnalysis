# %% [markdown]
# # Correlation of ROCKFORD PH Time Series

# %%
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
from statsmodels.multivariate.manova import MANOVA
import statsmodels  as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
from typing import Literal
from statsmodels.graphics.factorplots import interaction_plot
import statsmodels.stats.multicomp as multi
import seaborn as sns
import statsmodels as sm
from statsmodels.stats.anova import anova_lm

# %%
df=pd.read_excel('Time Series.xlsx')

# %%
df
# Out:
#      Rep  Trt Depth  WW19  SW19  WW20  SW20
# 0      1    1   0-3  3.96  4.02  4.03  4.29
# 1      1    2   0-3  4.98  5.46  5.56  5.26
# 2      1    3   0-3  5.76  5.87   NaN  5.56
# 3      1    4   0-3  4.10  3.85  3.91   NaN
# 4      1    5   0-3  4.66  5.45  5.50  4.98
# ..   ...  ...   ...   ...   ...   ...   ...
# 103    4    5  6-12  4.26  4.20  4.74  4.20
# 104    4    6  6-12  4.37  4.34  4.93  3.98
# 105    4    7  6-12  3.64  3.93  4.75  4.12
# 106    4    8  6-12  3.56  4.20  5.09  4.18
# 107    4    9  6-12  4.17  4.06  4.95  4.32
#
# [108 rows x 7 columns]

# %% [markdown]
# # Data Visualization

# %% [markdown]
# **CORELATION**

# %%
sns.pairplot(df,vars=['WW19','SW19','WW20','SW20'],kind='reg',size=1.5);
# Out:
# C:\Users\19292\AppData\Local\Programs\Common\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(df,hue='Depth',vars=['WW19','SW19','WW20','SW20'],size=1.5);
# Out:
# C:\Users\19292\AppData\Local\Programs\Common\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(df, kind='reg',hue='Depth',vars=['WW19','SW19','WW20','SW20'],size=1.5);
# Out:
# C:\Users\19292\AppData\Local\Programs\Common\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
df.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_c8de4_row0_col0, #T_c8de4_row1_col1, #T_c8de4_row2_col2, #T_c8de4_row3_col3, #T_c8de4_row4_col4, #T_c8de4_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c8de4_row0_col1, #T_c8de4_row0_col2, #T_c8de4_row0_col3, #T_c8de4_row0_col4, #T_c8de4_row1_col5, #T_c8de4_row4_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c8de4_row0_col5 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_c8de4_row1_col0, #T_c8de4_row1_col3 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_c8de4_row1_col2 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_c8de4_row1_col4 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_c8de4_row2_col0 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_c8de4_row2_col1 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_c8de4_row2_col3 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_c8de4_row2_col4 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_c8de4_row2_col5 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_c8de4_row3_col0 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_c8de4_row3_col1 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_c8de4_row3_col2 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_c8de4_row3_col4 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_c8de4_row3_col5 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_c8de4_row4_col1 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_c8de4_row4_col2 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_c8de4_row4_col3 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_c8de4_row4_col5 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_c8de4_row5_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_c8de4_row5_col1 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_c8de4_row5_col2 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_c8de4_row5_col3 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_c8de4_row5_col4 {
#   background-color: #dadce0;
#   color: #000000;
# }
# </style>
# <table id="T_c8de4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Rep</th>
#       <th class="col_heading level0 col1" >Trt</th>
#       <th class="col_heading level0 col2" >WW19</th>
#       <th class="col_heading level0 col3" >SW19</th>
#       <th class="col_heading level0 col4" >WW20</th>
#       <th class="col_heading level0 col5" >SW20</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8de4_level0_row0" class="row_heading level0 row0" >Rep</th>
#       <td id="T_c8de4_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_c8de4_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_c8de4_row0_col2" class="data row0 col2" >-0.072308</td>
#       <td id="T_c8de4_row0_col3" class="data row0 col3" >0.010908</td>
#       <td id="T_c8de4_row0_col4" class="data row0 col4" >-0.099520</td>
#       <td id="T_c8de4_row0_col5" class="data row0 col5" >0.158738</td>
#     </tr>
#     <tr>
#       <th id="T_c8de4_level0_row1" class="row_heading level0 row1" >Trt</th>
#       <td id="T_c8de4_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_c8de4_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_c8de4_row1_col2" class="data row1 col2" >0.068768</td>
#       <td id="T_c8de4_row1_col3" class="data row1 col3" >0.102918</td>
#       <td id="T_c8de4_row1_col4" class="data row1 col4" >0.022597</td>
#       <td id="T_c8de4_row1_col5" class="data row1 col5" >0.133962</td>
#     </tr>
#     <tr>
#       <th id="T_c8de4_level0_row2" class="row_heading level0 row2" >WW19</th>
#       <td id="T_c8de4_row2_col0" class="data row2 col0" >-0.072308</td>
#       <td id="T_c8de4_row2_col1" class="data row2 col1" >0.068768</td>
#       <td id="T_c8de4_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_c8de4_row2_col3" class="data row2 col3" >0.737090</td>
#       <td id="T_c8de4_row2_col4" class="data row2 col4" >0.611817</td>
#       <td id="T_c8de4_row2_col5" class="data row2 col5" >0.653800</td>
#     </tr>
#     <tr>
#       <th id="T_c8de4_level0_row3" class="row_heading level0 row3" >SW19</th>
#       <td id="T_c8de4_row3_col0" class="data row3 col0" >0.010908</td>
#       <td id="T_c8de4_row3_col1" class="data row3 col1" >0.102918</td>
#       <td id="T_c8de4_row3_col2" class="data row3 col2" >0.737090</td>
#       <td id="T_c8de4_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_c8de4_row3_col4" class="data row3 col4" >0.691219</td>
#       <td id="T_c8de4_row3_col5" class="data row3 col5" >0.842341</td>
#     </tr>
#     <tr>
#       <th id="T_c8de4_level0_row4" class="row_heading level0 row4" >WW20</th>
#       <td id="T_c8de4_row4_col0" class="data row4 col0" >-0.099520</td>
#       <td id="T_c8de4_row4_col1" class="data row4 col1" >0.022597</td>
#       <td id="T_c8de4_row4_col2" class="data row4 col2" >0.611817</td>
#       <td id="T_c8de4_row4_col3" class="data row4 col3" >0.691219</td>
#       <td id="T_c8de4_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_c8de4_row4_col5" class="data row4 col5" >0.440412</td>
#     </tr>
#     <tr>
#       <th id="T_c8de4_level0_row5" class="row_heading level0 row5" >SW20</th>
#       <td id="T_c8de4_row5_col0" class="data row5 col0" >0.158738</td>
#       <td id="T_c8de4_row5_col1" class="data row5 col1" >0.133962</td>
#       <td id="T_c8de4_row5_col2" class="data row5 col2" >0.653800</td>
#       <td id="T_c8de4_row5_col3" class="data row5 col3" >0.842341</td>
#       <td id="T_c8de4_row5_col4" class="data row5 col4" >0.440412</td>
#       <td id="T_c8de4_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
# Out:
# <AxesSubplot:>
